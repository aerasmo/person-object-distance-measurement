# %% [markdown]
# # Loading libs and algorithms

# %%
import numpy as np
import cv2 as cv
import os
from collections import defaultdict
from itertools import combinations
import threading
from os import listdir
from os.path import isfile, join
import time
# accuracy
CONF_THRESHHOLD = 0.6
NMS_THRESHHOLD = 0.4


# color and distance
CRITICAL_COL = (20, 20, 220) # red
WARNING_COL = (20, 120, 220) # orange
SAFE_COL = (20, 220, 20) # green
DIST_COL = (220, 20, 20) # blue
WARNING_DISTANCE = 500
CRITICAL_DISTANCE = 300

CLASS_NAMES = []
OBJ_COL = (20, 220, 20)

# load coco names
with open('classes.txt', 'r') as f:
    CLASS_NAMES = [cname.strip() for cname in f.readlines()]

# loading models 
weights = 'res\\yolov4-home_best.weights'
res = 'res\\yolov4-home.cfg'
net = cv.dnn.readNet(weights, res)
net.setPreferableBackend(cv.dnn.DNN_BACKEND_CUDA)
net.setPreferableTarget(cv.dnn.DNN_TARGET_CUDA)
model = cv.dnn_DetectionModel(net)
model.setInputParams(size=(416, 416), scale=1/255, swapRB=True)


def draw_text(img, text,
          font=cv.FONT_HERSHEY_PLAIN,
          pos=(0, 0),
          font_scale=3,
          font_thickness=2,
          text_color=(255, 255, 255),
          text_color_bg=SAFE_COL
          ):

    x, y = pos
    text_size, _ = cv.getTextSize(text, font, font_scale, font_thickness)
    text_w, text_h = text_size
    cv.rectangle(img, pos, (x + text_w + 10, y + text_h + 5), text_color_bg, -1)
    img = cv.putText(img, text, (x, y + text_h + font_scale - 1), font, font_scale, text_color, font_thickness)
    return img

def max_image_res(w, h, max_res):
    max_ = max(w, h)
    coeff = max_res / max_
    w *= coeff
    h *= coeff
    return (round(w), round(h))

# %% [markdown]
# # Object detection and Distance Detection algorithms

# %%
def object_detection(frame, model=model):
    objects = []
    classes, scores, boxes = model.detect(frame, CONF_THRESHHOLD, NMS_THRESHHOLD)
    # loop detected classes 
    for (class_id, _, box) in zip(classes, scores, boxes):
        class_name = CLASS_NAMES[class_id[0]]
        label = f"{class_name}"

        # setting default color 
        col = (20, 220, 20)

        # add text and bounding box
        frame = draw_text(frame, label, pos=(box[0]+5, box[1]+5), text_color_bg=col, font_scale=2)
        cv.rectangle(frame, box, col, thickness=4)

        # get coordinates
        (x, y) = (box[0], box[1])
        (w, h) = (box[2], box[3])
        left, right = ((x, y + h // 2), (x + w, y + h // 2))
        top, bottom = ((x + w//2, y), (x + w//2, y+h))
        
        # add data about objects to objects list
        objects.append((class_name, box, (top, right, bottom, left)))
    return frame, objects

def distance_detection(frame, objects, CRITICAL_DISTANCE=CRITICAL_DISTANCE, WARNING_DISTANCE=WARNING_DISTANCE, show_distance=False):
    level = 0
    color = (0, 0, 0)

    critical_set = set()
    for obj1, obj2 in list(combinations(objects, 2)):
        class_name1, box1, edges_a = obj1
        class_name2, box2, edges_b = obj2

        # break
        if (class_name1 == 'person' and class_name2 == 'person') or \
            (class_name1 != 'person' and class_name2 != 'person'):
            continue


        tl1, tr1 = (( box1[0], box1[1] ), ( box1[0] + box1[2], box1[1]))
        bl1, br1 = (( box1[0], box1[1] + box1[3]), ( box1[0] + box1[2], box1[1] + box1[3]))

        tl2, tr2 = (( box2[0], box2[1] ), ( box2[0] + box2[2], box2[1]))
        bl2, br2 = (( box2[0], box2[1] + box2[3]), ( box2[0] + box2[2], box2[1] + box2[3]))

        # caring about only x and ys
        b1x1, b1x2, = (box1[0], box1[0] + box1[2] )
        b1y1, b1y2, = (box1[1], box1[1] + box1[3] )

        b2x1, b2x2, = (box2[0], box2[0] + box2[2] )
        b2y1, b2y2, = (box2[1], box2[1] + box2[3] )

        overlap = False
        if ((b2x1 >= b1x1 and b2x1 <= b1x2) or (b2x2 >= b1x1 and b2x2 <= b1x2)) \
            and ((b2y1 >= b1y1 and b2y1 <= b1y2) or (b2y2 >= b1y1 and b2y2 <= b1y2)):
                overlap = True
                color = CRITICAL_COL
                level = 2
        
        min_distance = None
        case = None
        # checking for corner candidates:
        if (b2x2 < b1x1):
            if (b2y2 < b1y1):
                case = 'tl'
                # distance = br2 and tl1 
                coord_a = tl1
                coord_b = br2

                min_distance = ()
            elif (b2y1 > b1y2):
                case = 'bl' 
                # distance = tr2 and bl1
                coord_a = bl1
                coord_b = tr2
        if (b2x1 > b1x2):
            if (b2y2 < b1y1):
                case = 'tr'
                # distance = tr1 and bl2
                coord_a = tr1
                coord_b = bl2
            elif (b2y1 > b1y2):
                case = 'br'
                # distance = tl2 and br1
                coord_a = br1
                coord_b = tl2
            
        # gettingdistances
        distances = []
        code = None
        if not case:
            # l - r
            distance = abs(b1x1 - b2x2)
            min_distance = distance
            code = 'lr'
            # r - l
            distance = abs(b1x2 - b2x1)
            if distance < min_distance:
                min_distance = distance
                code = 'rl'

            # u - d
            distance = abs(b1y1 - b2y2)
            if distance < min_distance:
                min_distance = distance
                code = 'ud'

            # d - u
            distance = abs(b1y2 - b2y1)
            if distance < min_distance:
                min_distance = distance
                code = 'du'

            # checking for codes 
            if code == 'lr':
                if b1y1 > b2y1: # if b1 is lower
                    coord_a = tl1
                    coord_b = (b2x2 , tl1[1])
                elif b1y1 < b2y1: # if b1 is higher
                    coord_a = (b1x1 , tr2[1])
                    coord_b = tr2
                else:
                    coord_a = (b1x1, (b1y1 + b1y2) // 2 )
                    coord_b = (b2x2, (b2y1 + b2y2) // 2 )
            elif code == 'rl':
                if b1y1 > b2y1: # if b1 is lower
                    coord_a = tr1
                    coord_b = (b2x1, tr1[1])
                elif b1y1 < b2y1: # if b1 is higher
                    coord_a = (b1x2, tl2[1])
                    coord_b = tl2
                else:
                    coord_a = (b1x2, (b1y1 + b1y2) // 2 )
                    coord_b = (b2x1, (b2y1 + b2y2) // 2 )
            elif code == 'ud':
                if b1x1 > b2x1: # if b1 is lower
                    coord_a = tl1
                    coord_b = (tl1[0] , b2y2)
                elif b1x1 < b2x1: # if b1 is higher
                    coord_a = (bl2[0], b1y1)
                    coord_b = bl2
                else:
                    coord_a = ((b1x1 + b1x2) // 2, b1y1 )
                    coord_b = ((b2x1 + b2x2) // 2, b2y2 )
            elif code == 'du':
                if b1x1 > b2x1: # if b1 is lower
                    coord_a = bl1
                    coord_b = (bl1[0] , b2y1)
                elif b1x1 < b2x1: # if b1 is higher
                    coord_a = (tl2[0], b1y2)
                    coord_b = tl2
                else:
                    coord_a = ((b1x1 + b1x2) // 2, b1y2 )
                    coord_b = ((b2x1 + b2x2) // 2, b2y1 )

        # distance formula ( (x2 - x1) ^ 2 + (y2 - y1) ^2 ) ** 0.5
        # min distance

        
        # checking for distance 
        if not overlap:
            if case: # corners
                # distance formula ( (x2 - x1) ^ 2 + (y2 - y1) ^2 ) ** 0.5
                min_distance = (((coord_b[0] - coord_a[0]) ** 2) + (coord_b[1] - coord_a[1]) ** 2) ** 0.5
                # frame = cv.line(frame, (coord_a[0], coord_a[1]), (coord_b[0], coord_b[1]), DIST_COL, thickness=4)
            if min_distance <= CRITICAL_DISTANCE:
                color = CRITICAL_COL
                level = 2
                if show_distance: frame = cv.line(frame, (coord_a[0], coord_a[1]), (coord_b[0], coord_b[1]), CRITICAL_COL, thickness=4)
            elif min_distance <= WARNING_DISTANCE:
                level = 1
                color = WARNING_COL
                if show_distance: frame = cv.line(frame, (coord_a[0], coord_a[1]), (coord_b[0], coord_b[1]), WARNING_COL, thickness=4)
            else:
                level = 0
                color = SAFE_COL
                if show_distance: frame = cv.line(frame, (coord_a[0], coord_a[1]), (coord_b[0], coord_b[1]), DIST_COL, thickness=4)
        else:
            level = 2
            color = CRITICAL_COL

        if hex(id(obj1)) not in critical_set:
            frame = cv.rectangle(frame, box1, color, thickness=4) 
            frame = draw_text(frame, class_name1, pos=(box1[0]+5, box1[1]+5), text_color_bg=color, font_scale=2)
        
        if hex(id(obj2)) not in critical_set:
            frame = cv.rectangle(frame, box2, color, thickness=4) 
            frame = draw_text(frame, class_name2, pos=(box2[0]+5, box2[1]+5), text_color_bg=color, font_scale=2)

        if level == 2:
            critical_set.add(hex(id(obj1)))
            critical_set.add(hex(id(obj2)))

    return frame, level, color

# %% [markdown]
# ## Detecting Violations on a folder with images

# %%
# as a service: checking distance violation on a folder of 25 images
def detect_on_image(path, model=None, max_size=416, save_modified=True, save_raw=False):
    iframe = cv.imread(path) # orig image
    directory, file = os.path.split(path)
    if not model:
        frame, objects = object_detection(iframe)
    else:
        frame, objects = object_detection(iframe, model)

    if len(objects) > 1:
        frame, level, color = distance_detection(frame, objects, CRITICAL_DISTANCE=30, WARNING_DISTANCE=50)
        print(f"viewed: {path}, level: {level}, color: {color}")
        if level > 0:
            print(f"-violation (level: {level})")
            result = os.path.join(directory, 'violations')
            if not os.path.exists(result):
                print("violations folder does not exist. Creating folder")
                os.mkdir(result)
            cv.imwrite(os.path.join(result, file), frame)
            print(f"saved {file} to /violations")
            if save_raw:
                filename, ext = os.path.splitext(file)
                filename += f"_raw{ext}"
                cv.imwrite(os.path.join(directory, 'violations', filename), cv.imread(path))
    else:
        print(f"viewed: {path}, there are there are no recognizable objects")


def main():
    # loading models 
    net = cv.dnn.readNet('res\\yolov4-home_best.weights', 'res\\yolov4-home.cfg')
    net.setPreferableBackend(cv.dnn.DNN_BACKEND_CUDA)
    net.setPreferableTarget(cv.dnn.DNN_TARGET_CUDA)
    model = cv.dnn_DetectionModel(net) 
    model.setInputParams(size=(416, 416), scale=1/255, swapRB=True)
    # detecting on /test directory
    test_path = '.\\test\\image'

    images = [os.path.join(test_path, f) for f in listdir(test_path) if isfile(join(test_path, f)) and f.endswith('.jpg')][:100]
    for path in images:
        detect_on_image(path, model, save_raw=True)
# main()
# 820 size ---
# test 1: 25 images takes 3.9 seconds 
# test 2: 100 images takes 9.6 seconds
# test 3: 1000 images - 1m23 seconds ~ 1m43 seconds 
# ---
# test 4: 1000 images (512 size)  - 1m 22s

# %% [markdown]
# ## Detecting Violations on a video file

# %%
# as a service: detecting violations on a video file
import time
import copy
def detect_on_video(path, model=None, max_size=512, save_modified=True, save_raw=False):
    cap = cv.VideoCapture(path)
    prev_time = time.time()
    directory, file = os.path.split(path)
    filename, ext = os.path.splitext(file)

    allowed_saving = True
    idx = 1
    frame_id = 1
    # generate violation folder
    result = os.path.join(directory, 'violations', filename)
    if not os.path.exists(result):
        print("violation folder does not exist. Creating folder")
        os.makedirs(result)
    while True:
        ret, frame = cap.read()
        if ret == False:
            break

        height, width = frame.shape[:2]
        frame = cv.resize(frame, max_image_res(width, height, max_size), interpolation = cv.INTER_CUBIC)
        frame_raw = copy.deepcopy(frame)
        if not model:
            frame, objects = object_detection(frame)
        else:
            frame, objects = object_detection(frame, model)

        if len(objects) > 1:
            frame, level, color = distance_detection(frame, objects, CRITICAL_DISTANCE=30, WARNING_DISTANCE=50)
            print(f"viewed: {path} frame: {frame_id}, level: {level}, color: {color}")
            if level > 0:
                print(f"-violation (level: {level})")
                if allowed_saving:
                    if save_modified:
                        modified = filename + f"_{idx}.jpg"
                        cv.imwrite(os.path.join(result, modified), frame)
                        print(f"saved modified {filename} to /violations folder")
                        allowed_saving = False
                    if save_raw:
                        raw = filename + f"_{idx}_raw.jpg"
                        cv.imwrite(os.path.join(result, raw), frame_raw)
                        print(f"saved raw {filename} to /violations folder")
                    idx += 1
                    
                if not allowed_saving:
                    if time.time() - prev_time >= 3:
                        allowed_saving = True
                        prev_time = time.time()

        else:
            print(f"viewed: {path}, frame: {frame_id}, there are there are no recognizable objects")
        frame_id += 1
            
def main():
    # loading models 
    net = cv.dnn.readNet('res\\yolov4-home_best.weights', 'res\\yolov4-home.cfg')
    net.setPreferableBackend(cv.dnn.DNN_BACKEND_CUDA)
    net.setPreferableTarget(cv.dnn.DNN_TARGET_CUDA)
    model = cv.dnn_DetectionModel(net)
    model.setInputParams(size=(416, 416), scale=1/255, swapRB=True)
    # detecting on /test directory
    test_path = '.\\test\\video'
    # detecting on video
    # path = os.path.join(test_path, 'man.mkv')
    path = os.path.join(test_path, 'festivalyurifancam.mp4')
    detect_on_video(path, save_raw=True)
# main()
# test 1: 5minute37second cctv video feed took 13 minutes to check 
# test 2: festival yuri fancam (2minute video) took 4m 49.9 seconds to check

# %% [markdown]
# ## Detecting violations on a Webcam feed

# %%
# as a service: detecting violations on a single webcam feed
import time
import datetime
import copy
def detect_on_feed(output_path, name, capture=0, model=None, max_size=512, save_modified=True, save_raw=False):
    cap = cv.VideoCapture(capture)
    
    prev_time = time.time()

    allowed_saving = True
    frame_id = 1
    # generate violation folder
    result = os.path.join(output_path, name)
    if not os.path.exists(result):
        print("violation folder does not exist. Creating folder")
        os.makedirs(result)
    while True:
        ret, frame = cap.read()
        if ret == False:
            print("False")
            break

        height, width = frame.shape[:2]
        frame = cv.resize(frame, max_image_res(width, height, max_size), interpolation = cv.INTER_CUBIC)
        frame_raw = copy.deepcopy(frame)
        if not model:
            frame, objects = object_detection(frame)
        else:
            frame, objects = object_detection(frame, model)

        if len(objects) > 1:
            frame, level, color = distance_detection(frame, objects, CRITICAL_DISTANCE=30, WARNING_DISTANCE=50)
            print(f"viewed: {name} frame: {frame_id}, level: {level}, color: {color}")
            if level > 0:
                print(f"-violation (level: {level})")
                if allowed_saving:
                    timestamp = datetime.datetime.now().strftime("%Y-%m-%d-%H_%M_%S")
                    if save_modified:
                        modified = f"{timestamp}.jpg"
                        cv.imwrite(os.path.join(result, modified), frame)
                        print(f"saved modified frame to /violations folder. detected on {timestamp} ")
                        allowed_saving = False
                    if save_raw:
                        raw = f"{timestamp}_raw.jpg"
                        cv.imwrite(os.path.join(result, raw), frame_raw)
                        print(f"saved raw frame to /violations folder. detected on {timestamp} ")
                    
                if not allowed_saving:
                    if time.time() - prev_time >= 3:
                        allowed_saving = True
                        prev_time = time.time()

        else:
            print(f"viewed: {name}, frame: {frame_id}, there are there are no recognizable objects")
        frame_id += 1
            
def main():
    # loading models 
    net = cv.dnn.readNet('res\\yolov4-home_best.weights', 'res\\yolov4-home.cfg')
    net.setPreferableBackend(cv.dnn.DNN_BACKEND_CUDA)
    net.setPreferableTarget(cv.dnn.DNN_TARGET_CUDA)
    model = cv.dnn_DetectionModel(net)
    model.setInputParams(size=(416, 416), scale=1/255, swapRB=True)
    output_path = '.\\output\\capture\\no_ui'
    detect_on_feed(output_path, 'webcam 1', save_raw=True)
# main()

# %% [markdown]
# ## Detecting violations on 2 webcam feeds

# %%
# as a service: detecting violations on 2 webcam feeds
import time
import datetime
import copy
import threading 

def detect_on_feed(output_path, name, capture=0, model=None, max_size=512, save_modified=True, save_raw=False):
    cap = cv.VideoCapture(capture)
    
    prev_time = time.time()

    allowed_saving = True
    frame_id = 1
    # generate violation folder
    result = os.path.join(output_path, name)
    if not os.path.exists(result):
        print("violation folder does not exist. Creating folder")
        os.makedirs(result)
    while True:
        ret, frame = cap.read()
        if ret == False:
            print("False")
            break

        height, width = frame.shape[:2]
        frame = cv.resize(frame, max_image_res(width, height, max_size), interpolation = cv.INTER_CUBIC)
        frame_raw = copy.deepcopy(frame)
        if not model:
            frame, objects = object_detection(frame)
        else:
            frame, objects = object_detection(frame, model)

        if len(objects) > 1:
            frame, level, color = distance_detection(frame, objects, CRITICAL_DISTANCE=30, WARNING_DISTANCE=50)
            print(f"viewed: {name} frame: {frame_id}, level: {level}, color: {color}")
            if level > 0:
                print(f"-violation (level: {level})")
                if allowed_saving:
                    timestamp = datetime.datetime.now().strftime("%Y-%m-%d-%H_%M_%S")
                    if save_modified:
                        modified = f"{timestamp}.jpg"
                        cv.imwrite(os.path.join(result, modified), frame)
                        print(f"saved modified frame to /violations folder. detected on {timestamp} ")
                        allowed_saving = False
                    if save_raw:
                        raw = f"{timestamp}_raw.jpg"
                        cv.imwrite(os.path.join(result, raw), frame_raw)
                        print(f"saved raw frame to /violations folder. detected on {timestamp} ")
                    
                if not allowed_saving:
                    if time.time() - prev_time >= 3:
                        allowed_saving = True
                        prev_time = time.time()

        else:
            print(f"viewed: {name}, frame: {frame_id}, there are there are no recognizable objects")
        frame_id += 1

def main(name, camera):
    # loading models 
    net = cv.dnn.readNet('res\\yolov4-home_best.weights', 'res\\yolov4-home.cfg')
    net.setPreferableBackend(cv.dnn.DNN_BACKEND_CUDA)
    net.setPreferableTarget(cv.dnn.DNN_TARGET_CUDA)
    model = cv.dnn_DetectionModel(net)
    model.setInputParams(size=(416, 416), scale=1/255, swapRB=True)
    output_path = '.\\output\\capture\\no_ui'
    detect_on_feed(output_path, name, camera, model=model, save_raw=True, save_modified=True)

# detecting on different webcams on different threads
x = threading.Thread(target=main, args=('webcam 1', 0))
y = threading.Thread(target=main, args=('webcam 2', 1))
x.start()
y.start()
# Out:
# viewed: webcam 2, frame: 1, there are there are no recognizable objects
# viewed: webcam 2, frame: 2, there are there are no recognizable objects
# viewed: webcam 2, frame: 3, there are there are no recognizable objects
# viewed: webcam 2, frame: 4, there are there are no recognizable objects
# viewed: webcam 2, frame: 5, there are there are no recognizable objects
# viewed: webcam 2, frame: 6, there are there are no recognizable objects
# viewed: webcam 2, frame: 7, there are there are no recognizable objects
# viewed: webcam 2, frame: 8, there are there are no recognizable objects
# viewed: webcam 2, frame: 9, there are there are no recognizable objects
# viewed: webcam 2, frame: 10, there are there are no recognizable objects
# viewed: webcam 2, frame: 11, there are there are no recognizable objects
# viewed: webcam 2, frame: 12, there are there are no recognizable objects
# viewed: webcam 2, frame: 13, there are there are no recognizable objects
# viewed: webcam 1, frame: 1, there are there are no recognizable objects
# viewed: webcam 2, frame: 14, there are there are no recognizable objects
# viewed: webcam 1, frame: 2, there are there are no recognizable objects
# viewed: webcam 2, frame: 15, there are there are no recognizable objects
# viewed: webcam 1, frame: 3, there are there are no recognizable objects
# viewed: webcam 2, frame: 16, there are there are no recognizable objects
# viewed: webcam 1, frame: 4, there are there are no recognizable objects
# viewed: webcam 2, frame: 17, there are there are no recognizable objects
# viewed: webcam 1, frame: 5, there are there are no recognizable objects
# viewed: webcam 2, frame: 18, there are there are no recognizable objects
# viewed: webcam 2, frame: 19, there are there are no recognizable objects
# viewed: webcam 1, frame: 6, there are there are no recognizable objects
# viewed: webcam 2, frame: 20, there are there are no recognizable objects
# viewed: webcam 1, frame: 7, there are there are no recognizable objects
# viewed: webcam 2 frame: 21, level: 2, color: (20, 20, 220)
# -violation (level: 2)
# viewed: webcam 1, frame: 8, there are there are no recognizable objects
# saved modified frame to /violations folder. detected on 2022-01-08-18_22_36
# saved raw frame to /violations folder. detected on 2022-01-08-18_22_36
# viewed: webcam 1, frame: 9, there are there are no recognizable objects
# viewed: webcam 2, frame: 22, there are there are no recognizable objects
# viewed: webcam 1, frame: 10, there are there are no recognizable objects
# viewed: webcam 2 frame: 23, level: 2, color: (20, 20, 220)
# -violation (level: 2)
# saved modified frame to /violations folder. detected on 2022-01-08-18_22_36
# saved raw frame to /violations folder. detected on 2022-01-08-18_22_36
# viewed: webcam 1, frame: 11, there are there are no recognizable objects
# viewed: webcam 2, frame: 24, there are there are no recognizable objects
# viewed: webcam 1, frame: 12, there are there are no recognizable objects
# viewed: webcam 2, frame: 25, there are there are no recognizable objects
# viewed: webcam 2, frame: 26, there are there are no recognizable objectsviewed: webcam 1, frame: 13, there are there are no recognizable objects
#
# viewed: webcam 2, frame: 27, there are there are no recognizable objects
# viewed: webcam 1, frame: 14, there are there are no recognizable objects
# viewed: webcam 2, frame: 28, there are there are no recognizable objects
# viewed: webcam 1, frame: 15, there are there are no recognizable objects
# viewed: webcam 1, frame: 16, there are there are no recognizable objects
# viewed: webcam 2, frame: 29, there are there are no recognizable objects
# viewed: webcam 1, frame: 17, there are there are no recognizable objects
# viewed: webcam 2, frame: 30, there are there are no recognizable objects
# viewed: webcam 1, frame: 18, there are there are no recognizable objectsviewed: webcam 2, frame: 31, there are there are no recognizable objects
#
# viewed: webcam 2, frame: 32, there are there are no recognizable objects
# viewed: webcam 1, frame: 19, there are there are no recognizable objects
# viewed: webcam 2, frame: 33, there are there are no recognizable objects
# viewed: webcam 1, frame: 20, there are there are no recognizable objects
# viewed: webcam 2, frame: 34, there are there are no recognizable objects
# viewed: webcam 1, frame: 21, there are there are no recognizable objects
# viewed: webcam 2, frame: 35, there are there are no recognizable objects
# viewed: webcam 1, frame: 22, there are there are no recognizable objects
# viewed: webcam 2, frame: 36, there are there are no recognizable objects
# viewed: webcam 1, frame: 23, there are there are no recognizable objects
# viewed: webcam 2, frame: 37, there are there are no recognizable objects
# viewed: webcam 1, frame: 24, there are there are no recognizable objects
# viewed: webcam 1, frame: 25, there are there are no recognizable objectsviewed: webcam 2, frame: 38, there are there are no recognizable objects
#
# viewed: webcam 2, frame: 39, there are there are no recognizable objects
# viewed: webcam 1, frame: 26, there are there are no recognizable objects
# viewed: webcam 2, frame: 40, there are there are no recognizable objects
# viewed: webcam 1, frame: 27, there are there are no recognizable objects
# viewed: webcam 2, frame: 41, there are there are no recognizable objects
# viewed: webcam 1, frame: 28, there are there are no recognizable objects
# viewed: webcam 2, frame: 42, there are there are no recognizable objects
# viewed: webcam 1, frame: 29, there are there are no recognizable objects
# viewed: webcam 2, frame: 43, there are there are no recognizable objects
# viewed: webcam 1, frame: 30, there are there are no recognizable objects
# viewed: webcam 2, frame: 44, there are there are no recognizable objectsviewed: webcam 1, frame: 31, there are there are no recognizable objects
#
# viewed: webcam 2, frame: 45, there are there are no recognizable objects
# viewed: webcam 1, frame: 32, there are there are no recognizable objects
# viewed: webcam 2, frame: 46, there are there are no recognizable objects
# viewed: webcam 1, frame: 33, there are there are no recognizable objects
# viewed: webcam 2, frame: 47, there are there are no recognizable objects
# viewed: webcam 1, frame: 34, there are there are no recognizable objects
# viewed: webcam 2, frame: 48, there are there are no recognizable objects
# viewed: webcam 1, frame: 35, there are there are no recognizable objects
# viewed: webcam 2, frame: 49, there are there are no recognizable objects
# viewed: webcam 1, frame: 36, there are there are no recognizable objects
# viewed: webcam 2, frame: 50, there are there are no recognizable objects
# viewed: webcam 1, frame: 37, there are there are no recognizable objects
# viewed: webcam 2, frame: 51, there are there are no recognizable objects
# viewed: webcam 1, frame: 38, there are there are no recognizable objects
# viewed: webcam 2, frame: 52, there are there are no recognizable objects
# viewed: webcam 1, frame: 39, there are there are no recognizable objects
# viewed: webcam 2, frame: 53, there are there are no recognizable objects
# viewed: webcam 1, frame: 40, there are there are no recognizable objects
# viewed: webcam 2, frame: 54, there are there are no recognizable objects
# viewed: webcam 1, frame: 41, there are there are no recognizable objects
# viewed: webcam 2, frame: 55, there are there are no recognizable objects
# viewed: webcam 1, frame: 42, there are there are no recognizable objects
# viewed: webcam 2, frame: 56, there are there are no recognizable objects
# viewed: webcam 1, frame: 43, there are there are no recognizable objects
# viewed: webcam 2, frame: 57, there are there are no recognizable objects
# viewed: webcam 1, frame: 44, there are there are no recognizable objects
# viewed: webcam 2, frame: 58, there are there are no recognizable objects
# viewed: webcam 1, frame: 45, there are there are no recognizable objects
# viewed: webcam 2, frame: 59, there are there are no recognizable objects
# viewed: webcam 1, frame: 46, there are there are no recognizable objects
# viewed: webcam 2, frame: 60, there are there are no recognizable objects
# viewed: webcam 1, frame: 47, there are there are no recognizable objects
# viewed: webcam 2, frame: 61, there are there are no recognizable objects
# viewed: webcam 1, frame: 48, there are there are no recognizable objects
# viewed: webcam 2, frame: 62, there are there are no recognizable objects
# viewed: webcam 1, frame: 49, there are there are no recognizable objects
# viewed: webcam 2, frame: 63, there are there are no recognizable objects
# viewed: webcam 1, frame: 50, there are there are no recognizable objects
# viewed: webcam 2, frame: 64, there are there are no recognizable objects
# viewed: webcam 1, frame: 51, there are there are no recognizable objects
# viewed: webcam 2, frame: 65, there are there are no recognizable objects
# viewed: webcam 1, frame: 52, there are there are no recognizable objects
# viewed: webcam 2, frame: 66, there are there are no recognizable objects
# viewed: webcam 1, frame: 53, there are there are no recognizable objects
# viewed: webcam 2, frame: 67, there are there are no recognizable objects
# viewed: webcam 1, frame: 54, there are there are no recognizable objects
# viewed: webcam 1, frame: 55, there are there are no recognizable objects
# viewed: webcam 2, frame: 68, there are there are no recognizable objects
# viewed: webcam 1, frame: 56, there are there are no recognizable objects
# viewed: webcam 2, frame: 69, there are there are no recognizable objects
# viewed: webcam 1, frame: 57, there are there are no recognizable objects
# viewed: webcam 2, frame: 70, there are there are no recognizable objects
# viewed: webcam 1, frame: 58, there are there are no recognizable objects
# viewed: webcam 2, frame: 71, there are there are no recognizable objects
# viewed: webcam 1, frame: 59, there are there are no recognizable objects
# viewed: webcam 2, frame: 72, there are there are no recognizable objects
# viewed: webcam 1, frame: 60, there are there are no recognizable objects
# viewed: webcam 2, frame: 73, there are there are no recognizable objects
# viewed: webcam 1, frame: 61, there are there are no recognizable objects
# viewed: webcam 2, frame: 74, there are there are no recognizable objects
# viewed: webcam 1, frame: 62, there are there are no recognizable objects
# viewed: webcam 2, frame: 75, there are there are no recognizable objects
# viewed: webcam 1, frame: 63, there are there are no recognizable objects
# viewed: webcam 2, frame: 76, there are there are no recognizable objects
# viewed: webcam 1, frame: 64, there are there are no recognizable objects
# viewed: webcam 2, frame: 77, there are there are no recognizable objects
# viewed: webcam 1, frame: 65, there are there are no recognizable objects
# viewed: webcam 2, frame: 78, there are there are no recognizable objects
# viewed: webcam 1, frame: 66, there are there are no recognizable objects
# viewed: webcam 2, frame: 79, there are there are no recognizable objects
# viewed: webcam 1, frame: 67, there are there are no recognizable objects
# viewed: webcam 2, frame: 80, there are there are no recognizable objects
# viewed: webcam 1, frame: 68, there are there are no recognizable objects
# viewed: webcam 2, frame: 81, there are there are no recognizable objects
# viewed: webcam 1, frame: 69, there are there are no recognizable objects
# viewed: webcam 2, frame: 82, there are there are no recognizable objects
# viewed: webcam 1, frame: 70, there are there are no recognizable objects
# viewed: webcam 2, frame: 83, there are there are no recognizable objects
# viewed: webcam 1, frame: 71, there are there are no recognizable objects
# viewed: webcam 2, frame: 84, there are there are no recognizable objects
# viewed: webcam 1, frame: 72, there are there are no recognizable objects
# viewed: webcam 2, frame: 85, there are there are no recognizable objects
# viewed: webcam 1, frame: 73, there are there are no recognizable objects
# viewed: webcam 2, frame: 86, there are there are no recognizable objects
# viewed: webcam 1, frame: 74, there are there are no recognizable objects
# viewed: webcam 2, frame: 87, there are there are no recognizable objects
# viewed: webcam 1, frame: 75, there are there are no recognizable objects
# viewed: webcam 2, frame: 88, there are there are no recognizable objects
# viewed: webcam 1, frame: 76, there are there are no recognizable objects
# viewed: webcam 2, frame: 89, there are there are no recognizable objects
# viewed: webcam 2, frame: 90, there are there are no recognizable objects
# viewed: webcam 1, frame: 77, there are there are no recognizable objects
# viewed: webcam 2, frame: 91, there are there are no recognizable objects
# viewed: webcam 1, frame: 78, there are there are no recognizable objects
# viewed: webcam 2, frame: 92, there are there are no recognizable objects
# viewed: webcam 1, frame: 79, there are there are no recognizable objects
# viewed: webcam 2, frame: 93, there are there are no recognizable objects
# viewed: webcam 1, frame: 80, there are there are no recognizable objects
# viewed: webcam 2, frame: 94, there are there are no recognizable objects
# viewed: webcam 1, frame: 81, there are there are no recognizable objects
# viewed: webcam 2, frame: 95, there are there are no recognizable objects
# viewed: webcam 1, frame: 82, there are there are no recognizable objects
# viewed: webcam 2, frame: 96, there are there are no recognizable objects
# viewed: webcam 1, frame: 83, there are there are no recognizable objects
# viewed: webcam 2, frame: 97, there are there are no recognizable objects
# viewed: webcam 1, frame: 84, there are there are no recognizable objects
# viewed: webcam 2, frame: 98, there are there are no recognizable objects
# viewed: webcam 1, frame: 85, there are there are no recognizable objects
# viewed: webcam 2, frame: 99, there are there are no recognizable objects
# viewed: webcam 1, frame: 86, there are there are no recognizable objects
# viewed: webcam 2, frame: 100, there are there are no recognizable objects
# viewed: webcam 1, frame: 87, there are there are no recognizable objects
# viewed: webcam 2, frame: 101, there are there are no recognizable objects
# viewed: webcam 1, frame: 88, there are there are no recognizable objects
# viewed: webcam 2, frame: 102, there are there are no recognizable objects
# viewed: webcam 1, frame: 89, there are there are no recognizable objects
# viewed: webcam 2, frame: 103, there are there are no recognizable objects
# viewed: webcam 1, frame: 90, there are there are no recognizable objects
# viewed: webcam 2, frame: 104, there are there are no recognizable objects
# viewed: webcam 1, frame: 91, there are there are no recognizable objects
# viewed: webcam 2, frame: 105, there are there are no recognizable objects
# viewed: webcam 1, frame: 92, there are there are no recognizable objects
# viewed: webcam 2, frame: 106, there are there are no recognizable objects
# viewed: webcam 1, frame: 93, there are there are no recognizable objects
# viewed: webcam 2, frame: 107, there are there are no recognizable objects
# viewed: webcam 1, frame: 94, there are there are no recognizable objects
# viewed: webcam 2, frame: 108, there are there are no recognizable objects
# viewed: webcam 1, frame: 95, there are there are no recognizable objects
# viewed: webcam 2, frame: 109, there are there are no recognizable objects
# viewed: webcam 1, frame: 96, there are there are no recognizable objects
# viewed: webcam 2, frame: 110, there are there are no recognizable objects
# viewed: webcam 1, frame: 97, there are there are no recognizable objects
# viewed: webcam 2, frame: 111, there are there are no recognizable objects
# viewed: webcam 1, frame: 98, there are there are no recognizable objects
# viewed: webcam 2, frame: 112, there are there are no recognizable objects
# viewed: webcam 1, frame: 99, there are there are no recognizable objects
# viewed: webcam 2, frame: 113, there are there are no recognizable objects
# viewed: webcam 1, frame: 100, there are there are no recognizable objects
# viewed: webcam 2, frame: 114, there are there are no recognizable objects
# viewed: webcam 1, frame: 101, there are there are no recognizable objects
# viewed: webcam 2, frame: 115, there are there are no recognizable objects
# viewed: webcam 1, frame: 102, there are there are no recognizable objects
# viewed: webcam 2, frame: 116, there are there are no recognizable objects
# viewed: webcam 1, frame: 103, there are there are no recognizable objects
# viewed: webcam 2, frame: 117, there are there are no recognizable objects
# viewed: webcam 1, frame: 104, there are there are no recognizable objects
# viewed: webcam 2, frame: 118, there are there are no recognizable objects
# viewed: webcam 1, frame: 105, there are there are no recognizable objects
# viewed: webcam 2, frame: 119, there are there are no recognizable objects
# viewed: webcam 1, frame: 106, there are there are no recognizable objects
# viewed: webcam 2, frame: 120, there are there are no recognizable objects
# viewed: webcam 1, frame: 107, there are there are no recognizable objects
# viewed: webcam 2, frame: 121, there are there are no recognizable objects
# viewed: webcam 1, frame: 108, there are there are no recognizable objects
# viewed: webcam 2, frame: 122, there are there are no recognizable objects
# viewed: webcam 1, frame: 109, there are there are no recognizable objects
# viewed: webcam 2, frame: 123, there are there are no recognizable objects
# viewed: webcam 1, frame: 110, there are there are no recognizable objects
# viewed: webcam 2, frame: 124, there are there are no recognizable objects
# viewed: webcam 1, frame: 111, there are there are no recognizable objects
# viewed: webcam 2, frame: 125, there are there are no recognizable objects
# viewed: webcam 1, frame: 112, there are there are no recognizable objects
# viewed: webcam 2, frame: 126, there are there are no recognizable objects
# viewed: webcam 1, frame: 113, there are there are no recognizable objects
# viewed: webcam 2, frame: 127, there are there are no recognizable objects
# viewed: webcam 1, frame: 114, there are there are no recognizable objects
# viewed: webcam 2, frame: 128, there are there are no recognizable objects
# viewed: webcam 1, frame: 115, there are there are no recognizable objects
# viewed: webcam 2, frame: 129, there are there are no recognizable objects
# viewed: webcam 1, frame: 116, there are there are no recognizable objects
# viewed: webcam 2, frame: 130, there are there are no recognizable objects
# viewed: webcam 1, frame: 117, there are there are no recognizable objects
# viewed: webcam 2, frame: 131, there are there are no recognizable objects
# viewed: webcam 1, frame: 118, there are there are no recognizable objects
# viewed: webcam 2, frame: 132, there are there are no recognizable objects
# viewed: webcam 1, frame: 119, there are there are no recognizable objects
# viewed: webcam 2, frame: 133, there are there are no recognizable objects
# viewed: webcam 1, frame: 120, there are there are no recognizable objects
# viewed: webcam 2, frame: 134, there are there are no recognizable objects
# viewed: webcam 1, frame: 121, there are there are no recognizable objects
# viewed: webcam 2, frame: 135, there are there are no recognizable objects
# viewed: webcam 1, frame: 122, there are there are no recognizable objects
# viewed: webcam 2, frame: 136, there are there are no recognizable objects
# viewed: webcam 1, frame: 123, there are there are no recognizable objects
# viewed: webcam 2, frame: 137, there are there are no recognizable objects
# viewed: webcam 1, frame: 124, there are there are no recognizable objects
# viewed: webcam 2, frame: 138, there are there are no recognizable objects
# viewed: webcam 1, frame: 125, there are there are no recognizable objects
# viewed: webcam 2, frame: 139, there are there are no recognizable objects
# viewed: webcam 1, frame: 126, there are there are no recognizable objects
# viewed: webcam 2, frame: 140, there are there are no recognizable objects
# viewed: webcam 1, frame: 127, there are there are no recognizable objects
# viewed: webcam 2, frame: 141, there are there are no recognizable objects
# viewed: webcam 1, frame: 128, there are there are no recognizable objects
# viewed: webcam 2, frame: 142, there are there are no recognizable objects
# viewed: webcam 1, frame: 129, there are there are no recognizable objects
# viewed: webcam 2, frame: 143, there are there are no recognizable objects
# viewed: webcam 1, frame: 130, there are there are no recognizable objects
# viewed: webcam 2, frame: 144, there are there are no recognizable objects
# viewed: webcam 1, frame: 131, there are there are no recognizable objects
# viewed: webcam 2, frame: 145, there are there are no recognizable objects
# viewed: webcam 1, frame: 132, there are there are no recognizable objects
# viewed: webcam 2, frame: 146, there are there are no recognizable objects
# viewed: webcam 1, frame: 133, there are there are no recognizable objects
# viewed: webcam 2, frame: 147, there are there are no recognizable objects
# viewed: webcam 1, frame: 134, there are there are no recognizable objects
# viewed: webcam 2, frame: 148, there are there are no recognizable objects
# viewed: webcam 1, frame: 135, there are there are no recognizable objects
# viewed: webcam 2, frame: 149, there are there are no recognizable objects
# viewed: webcam 1, frame: 136, there are there are no recognizable objects
# viewed: webcam 2, frame: 150, there are there are no recognizable objects
# viewed: webcam 1, frame: 137, there are there are no recognizable objects
# viewed: webcam 2, frame: 151, there are there are no recognizable objects
# viewed: webcam 1, frame: 138, there are there are no recognizable objects
# viewed: webcam 2, frame: 152, there are there are no recognizable objects
# viewed: webcam 1, frame: 139, there are there are no recognizable objects
# viewed: webcam 2, frame: 153, there are there are no recognizable objects
# viewed: webcam 1, frame: 140, there are there are no recognizable objects
# viewed: webcam 2, frame: 154, there are there are no recognizable objects
# viewed: webcam 1, frame: 141, there are there are no recognizable objects
# viewed: webcam 2, frame: 155, there are there are no recognizable objects
# viewed: webcam 1, frame: 142, there are there are no recognizable objects
# viewed: webcam 2, frame: 156, there are there are no recognizable objects
# viewed: webcam 1, frame: 143, there are there are no recognizable objects
# viewed: webcam 2, frame: 157, there are there are no recognizable objects
# viewed: webcam 1, frame: 144, there are there are no recognizable objects
# viewed: webcam 2, frame: 158, there are there are no recognizable objects
# viewed: webcam 1, frame: 145, there are there are no recognizable objects
# viewed: webcam 2, frame: 159, there are there are no recognizable objects
# viewed: webcam 1, frame: 146, there are there are no recognizable objects
# viewed: webcam 2, frame: 160, there are there are no recognizable objects
# viewed: webcam 1, frame: 147, there are there are no recognizable objects
# viewed: webcam 2, frame: 161, there are there are no recognizable objects
# viewed: webcam 1, frame: 148, there are there are no recognizable objects
# viewed: webcam 2, frame: 162, there are there are no recognizable objects
# viewed: webcam 1, frame: 149, there are there are no recognizable objects
# viewed: webcam 2, frame: 163, there are there are no recognizable objects
# viewed: webcam 1, frame: 150, there are there are no recognizable objects
# viewed: webcam 2, frame: 164, there are there are no recognizable objects
# viewed: webcam 1, frame: 151, there are there are no recognizable objects
# viewed: webcam 2, frame: 165, there are there are no recognizable objects
# viewed: webcam 1, frame: 152, there are there are no recognizable objects
# viewed: webcam 2, frame: 166, there are there are no recognizable objects
# viewed: webcam 1, frame: 153, there are there are no recognizable objects
# viewed: webcam 2, frame: 167, there are there are no recognizable objects
# viewed: webcam 1, frame: 154, there are there are no recognizable objects
# viewed: webcam 2, frame: 168, there are there are no recognizable objects
# viewed: webcam 1, frame: 155, there are there are no recognizable objects
# viewed: webcam 2, frame: 169, there are there are no recognizable objects
# viewed: webcam 1, frame: 156, there are there are no recognizable objects
# viewed: webcam 2, frame: 170, there are there are no recognizable objects
# viewed: webcam 1, frame: 157, there are there are no recognizable objects
# viewed: webcam 2, frame: 171, there are there are no recognizable objects
# viewed: webcam 1, frame: 158, there are there are no recognizable objects
# viewed: webcam 2, frame: 172, there are there are no recognizable objects
# viewed: webcam 1, frame: 159, there are there are no recognizable objects
# viewed: webcam 2, frame: 173, there are there are no recognizable objects
# viewed: webcam 1, frame: 160, there are there are no recognizable objects
# viewed: webcam 2, frame: 174, there are there are no recognizable objects
# viewed: webcam 1, frame: 161, there are there are no recognizable objects
# viewed: webcam 2, frame: 175, there are there are no recognizable objects
# viewed: webcam 1, frame: 162, there are there are no recognizable objects
# viewed: webcam 2, frame: 176, there are there are no recognizable objects
# viewed: webcam 1, frame: 163, there are there are no recognizable objects
# viewed: webcam 2, frame: 177, there are there are no recognizable objects
# viewed: webcam 1, frame: 164, there are there are no recognizable objects
# viewed: webcam 2, frame: 178, there are there are no recognizable objects
# viewed: webcam 1, frame: 165, there are there are no recognizable objects
# viewed: webcam 2, frame: 179, there are there are no recognizable objects
# viewed: webcam 1, frame: 166, there are there are no recognizable objects
# viewed: webcam 2, frame: 180, there are there are no recognizable objects
# viewed: webcam 1, frame: 167, there are there are no recognizable objects
# viewed: webcam 2, frame: 181, there are there are no recognizable objects
# viewed: webcam 1, frame: 168, there are there are no recognizable objects
# viewed: webcam 2, frame: 182, there are there are no recognizable objects
# viewed: webcam 1, frame: 169, there are there are no recognizable objects
# viewed: webcam 2, frame: 183, there are there are no recognizable objects
# viewed: webcam 1, frame: 170, there are there are no recognizable objects
# viewed: webcam 2, frame: 184, there are there are no recognizable objects
# viewed: webcam 1, frame: 171, there are there are no recognizable objects
# viewed: webcam 2, frame: 185, there are there are no recognizable objects
# viewed: webcam 1, frame: 172, there are there are no recognizable objects
# viewed: webcam 2, frame: 186, there are there are no recognizable objects
# viewed: webcam 1, frame: 173, there are there are no recognizable objects
# viewed: webcam 2, frame: 187, there are there are no recognizable objects
# viewed: webcam 1, frame: 174, there are there are no recognizable objects
# viewed: webcam 2, frame: 188, there are there are no recognizable objects
# viewed: webcam 1, frame: 175, there are there are no recognizable objects
# viewed: webcam 2, frame: 189, there are there are no recognizable objects
# viewed: webcam 1, frame: 176, there are there are no recognizable objects
# viewed: webcam 2, frame: 190, there are there are no recognizable objects
# viewed: webcam 1, frame: 177, there are there are no recognizable objects
# viewed: webcam 2, frame: 191, there are there are no recognizable objects
# viewed: webcam 1, frame: 178, there are there are no recognizable objects
# viewed: webcam 2, frame: 192, there are there are no recognizable objects
# viewed: webcam 1, frame: 179, there are there are no recognizable objects
# viewed: webcam 2, frame: 193, there are there are no recognizable objects
# viewed: webcam 1, frame: 180, there are there are no recognizable objects
# viewed: webcam 2, frame: 194, there are there are no recognizable objects
# viewed: webcam 1, frame: 181, there are there are no recognizable objects
# viewed: webcam 2, frame: 195, there are there are no recognizable objects
# viewed: webcam 1, frame: 182, there are there are no recognizable objects
# viewed: webcam 2, frame: 196, there are there are no recognizable objects
# viewed: webcam 1, frame: 183, there are there are no recognizable objects
# viewed: webcam 2, frame: 197, there are there are no recognizable objects
# viewed: webcam 1, frame: 184, there are there are no recognizable objects
# viewed: webcam 2, frame: 198, there are there are no recognizable objects
# viewed: webcam 1, frame: 185, there are there are no recognizable objects
# viewed: webcam 2, frame: 199, there are there are no recognizable objects
# viewed: webcam 1, frame: 186, there are there are no recognizable objects
# viewed: webcam 2, frame: 200, there are there are no recognizable objects
# viewed: webcam 1, frame: 187, there are there are no recognizable objects
# viewed: webcam 2, frame: 201, there are there are no recognizable objects
# viewed: webcam 1, frame: 188, there are there are no recognizable objects
# viewed: webcam 2, frame: 202, there are there are no recognizable objects
# viewed: webcam 1, frame: 189, there are there are no recognizable objects
# viewed: webcam 2, frame: 203, there are there are no recognizable objects
# viewed: webcam 1, frame: 190, there are there are no recognizable objects
# viewed: webcam 2, frame: 204, there are there are no recognizable objects
# viewed: webcam 1, frame: 191, there are there are no recognizable objects
# viewed: webcam 2, frame: 205, there are there are no recognizable objects
# viewed: webcam 1, frame: 192, there are there are no recognizable objects
# viewed: webcam 2, frame: 206, there are there are no recognizable objects
# viewed: webcam 1, frame: 193, there are there are no recognizable objects
# viewed: webcam 2, frame: 207, there are there are no recognizable objects
# viewed: webcam 1, frame: 194, there are there are no recognizable objects
# viewed: webcam 2, frame: 208, there are there are no recognizable objects
# viewed: webcam 1, frame: 195, there are there are no recognizable objects
# viewed: webcam 2, frame: 209, there are there are no recognizable objects
# viewed: webcam 1, frame: 196, there are there are no recognizable objects
# viewed: webcam 2, frame: 210, there are there are no recognizable objects
# viewed: webcam 1, frame: 197, there are there are no recognizable objects
# viewed: webcam 2, frame: 211, there are there are no recognizable objects
# viewed: webcam 1, frame: 198, there are there are no recognizable objects
# viewed: webcam 2, frame: 212, there are there are no recognizable objects
# viewed: webcam 1, frame: 199, there are there are no recognizable objects
# viewed: webcam 2, frame: 213, there are there are no recognizable objects
# viewed: webcam 1, frame: 200, there are there are no recognizable objects
# viewed: webcam 2, frame: 214, there are there are no recognizable objects
# viewed: webcam 1, frame: 201, there are there are no recognizable objects
# viewed: webcam 2, frame: 215, there are there are no recognizable objects
# viewed: webcam 1, frame: 202, there are there are no recognizable objects
# viewed: webcam 2, frame: 216, there are there are no recognizable objects
# viewed: webcam 1, frame: 203, there are there are no recognizable objects
# viewed: webcam 2, frame: 217, there are there are no recognizable objects
# viewed: webcam 1, frame: 204, there are there are no recognizable objects
# viewed: webcam 2, frame: 218, there are there are no recognizable objects
# viewed: webcam 1, frame: 205, there are there are no recognizable objects
# viewed: webcam 2, frame: 219, there are there are no recognizable objects
# viewed: webcam 1, frame: 206, there are there are no recognizable objects
# viewed: webcam 2, frame: 220, there are there are no recognizable objects
# viewed: webcam 1, frame: 207, there are there are no recognizable objects
# viewed: webcam 2, frame: 221, there are there are no recognizable objects
# viewed: webcam 1, frame: 208, there are there are no recognizable objects
# viewed: webcam 2, frame: 222, there are there are no recognizable objects
# viewed: webcam 1, frame: 209, there are there are no recognizable objects
# viewed: webcam 2, frame: 223, there are there are no recognizable objects
# viewed: webcam 1, frame: 210, there are there are no recognizable objects
# viewed: webcam 2, frame: 224, there are there are no recognizable objects
# viewed: webcam 1, frame: 211, there are there are no recognizable objects
# viewed: webcam 2, frame: 225, there are there are no recognizable objects
# viewed: webcam 1, frame: 212, there are there are no recognizable objects
# viewed: webcam 2, frame: 226, there are there are no recognizable objects
# viewed: webcam 1, frame: 213, there are there are no recognizable objects
# viewed: webcam 2, frame: 227, there are there are no recognizable objects
# viewed: webcam 1, frame: 214, there are there are no recognizable objects
# viewed: webcam 2, frame: 228, there are there are no recognizable objects
# viewed: webcam 1, frame: 215, there are there are no recognizable objects
# viewed: webcam 2, frame: 229, there are there are no recognizable objects
# viewed: webcam 1, frame: 216, there are there are no recognizable objects
# viewed: webcam 2, frame: 230, there are there are no recognizable objects
# viewed: webcam 1, frame: 217, there are there are no recognizable objects
# viewed: webcam 2, frame: 231, there are there are no recognizable objects
# viewed: webcam 1, frame: 218, there are there are no recognizable objects
# viewed: webcam 2, frame: 232, there are there are no recognizable objects
# viewed: webcam 1, frame: 219, there are there are no recognizable objects
# viewed: webcam 2, frame: 233, there are there are no recognizable objects
# viewed: webcam 1, frame: 220, there are there are no recognizable objects
# viewed: webcam 2, frame: 234, there are there are no recognizable objects
# viewed: webcam 1, frame: 221, there are there are no recognizable objects
# viewed: webcam 2, frame: 235, there are there are no recognizable objects
# viewed: webcam 1, frame: 222, there are there are no recognizable objects
# viewed: webcam 2, frame: 236, there are there are no recognizable objects
# viewed: webcam 1, frame: 223, there are there are no recognizable objects
# viewed: webcam 2, frame: 237, there are there are no recognizable objects
# viewed: webcam 1, frame: 224, there are there are no recognizable objects
# viewed: webcam 2, frame: 238, there are there are no recognizable objects
# viewed: webcam 1, frame: 225, there are there are no recognizable objects
# viewed: webcam 2, frame: 239, there are there are no recognizable objects
# viewed: webcam 1, frame: 226, there are there are no recognizable objects
# viewed: webcam 2, frame: 240, there are there are no recognizable objects
# viewed: webcam 1, frame: 227, there are there are no recognizable objects
# viewed: webcam 2, frame: 241, there are there are no recognizable objects
# viewed: webcam 1, frame: 228, there are there are no recognizable objects
# viewed: webcam 2, frame: 242, there are there are no recognizable objects
# viewed: webcam 1, frame: 229, there are there are no recognizable objects
# viewed: webcam 2, frame: 243, there are there are no recognizable objects
# viewed: webcam 1, frame: 230, there are there are no recognizable objects
# viewed: webcam 2, frame: 244, there are there are no recognizable objects
# viewed: webcam 1, frame: 231, there are there are no recognizable objects
# viewed: webcam 2, frame: 245, there are there are no recognizable objects
# viewed: webcam 1, frame: 232, there are there are no recognizable objects
# viewed: webcam 2, frame: 246, there are there are no recognizable objects
# viewed: webcam 1, frame: 233, there are there are no recognizable objects
# viewed: webcam 1, frame: 234, there are there are no recognizable objects
# viewed: webcam 2, frame: 247, there are there are no recognizable objects
# viewed: webcam 1, frame: 235, there are there are no recognizable objects
# viewed: webcam 2, frame: 248, there are there are no recognizable objects
# viewed: webcam 1, frame: 236, there are there are no recognizable objects
# viewed: webcam 2, frame: 249, there are there are no recognizable objects
# viewed: webcam 1, frame: 237, there are there are no recognizable objects
# viewed: webcam 2, frame: 250, there are there are no recognizable objects
# viewed: webcam 1, frame: 238, there are there are no recognizable objects
# viewed: webcam 2, frame: 251, there are there are no recognizable objects
# viewed: webcam 1, frame: 239, there are there are no recognizable objects
# viewed: webcam 2, frame: 252, there are there are no recognizable objects
# viewed: webcam 1, frame: 240, there are there are no recognizable objects
# viewed: webcam 2, frame: 253, there are there are no recognizable objects
# viewed: webcam 1, frame: 241, there are there are no recognizable objects
# viewed: webcam 2, frame: 254, there are there are no recognizable objects
# viewed: webcam 1 frame: 242, level: 2, color: (20, 20, 220)
# -violation (level: 2)
# viewed: webcam 2, frame: 255, there are there are no recognizable objects
# saved modified frame to /violations folder. detected on 2022-01-08-18_23_06
# saved raw frame to /violations folder. detected on 2022-01-08-18_23_06
# viewed: webcam 2, frame: 256, there are there are no recognizable objects
# viewed: webcam 1, frame: 243, there are there are no recognizable objects
# viewed: webcam 2, frame: 257, there are there are no recognizable objects
# viewed: webcam 1, frame: 244, there are there are no recognizable objects
# viewed: webcam 2, frame: 258, there are there are no recognizable objects
# viewed: webcam 1, frame: 245, there are there are no recognizable objects
# viewed: webcam 2, frame: 259, there are there are no recognizable objects
# viewed: webcam 1, frame: 246, there are there are no recognizable objects
# viewed: webcam 2, frame: 260, there are there are no recognizable objects
# viewed: webcam 1, frame: 247, there are there are no recognizable objects
# viewed: webcam 2, frame: 261, there are there are no recognizable objects
# viewed: webcam 1, frame: 248, there are there are no recognizable objects
# viewed: webcam 2, frame: 262, there are there are no recognizable objects
# viewed: webcam 1, frame: 249, there are there are no recognizable objects
# viewed: webcam 2, frame: 263, there are there are no recognizable objects
# viewed: webcam 1, frame: 250, there are there are no recognizable objects
# viewed: webcam 2, frame: 264, there are there are no recognizable objects
# viewed: webcam 1, frame: 251, there are there are no recognizable objects
# viewed: webcam 2, frame: 265, there are there are no recognizable objects
# viewed: webcam 1, frame: 252, there are there are no recognizable objects
# viewed: webcam 2, frame: 266, there are there are no recognizable objects
# viewed: webcam 1, frame: 253, there are there are no recognizable objects
# viewed: webcam 2, frame: 267, there are there are no recognizable objects
# viewed: webcam 1, frame: 254, there are there are no recognizable objects
# viewed: webcam 2, frame: 268, there are there are no recognizable objects
# viewed: webcam 1, frame: 255, there are there are no recognizable objects
# viewed: webcam 2, frame: 269, there are there are no recognizable objects
# viewed: webcam 1, frame: 256, there are there are no recognizable objects
# viewed: webcam 2, frame: 270, there are there are no recognizable objects
# viewed: webcam 1, frame: 257, there are there are no recognizable objects
# viewed: webcam 2, frame: 271, there are there are no recognizable objects
# viewed: webcam 1, frame: 258, there are there are no recognizable objects
# viewed: webcam 2, frame: 272, there are there are no recognizable objects
# viewed: webcam 1, frame: 259, there are there are no recognizable objects
# viewed: webcam 2, frame: 273, there are there are no recognizable objects
# viewed: webcam 1, frame: 260, there are there are no recognizable objects
# viewed: webcam 2, frame: 274, there are there are no recognizable objects
# viewed: webcam 1, frame: 261, there are there are no recognizable objects
# viewed: webcam 2, frame: 275, there are there are no recognizable objects
# viewed: webcam 1, frame: 262, there are there are no recognizable objects
# viewed: webcam 2, frame: 276, there are there are no recognizable objects
# viewed: webcam 1, frame: 263, there are there are no recognizable objects
# viewed: webcam 2, frame: 277, there are there are no recognizable objects
# viewed: webcam 1, frame: 264, there are there are no recognizable objects
# viewed: webcam 2, frame: 278, there are there are no recognizable objects
# viewed: webcam 1, frame: 265, there are there are no recognizable objects
# viewed: webcam 2, frame: 279, there are there are no recognizable objects
# viewed: webcam 1, frame: 266, there are there are no recognizable objects
# viewed: webcam 2, frame: 280, there are there are no recognizable objects
# viewed: webcam 1, frame: 267, there are there are no recognizable objects
# viewed: webcam 2, frame: 281, there are there are no recognizable objects
# viewed: webcam 1, frame: 268, there are there are no recognizable objects
# viewed: webcam 2, frame: 282, there are there are no recognizable objects
# viewed: webcam 1, frame: 269, there are there are no recognizable objects
# viewed: webcam 2, frame: 283, there are there are no recognizable objects
# viewed: webcam 1, frame: 270, there are there are no recognizable objects
# viewed: webcam 2, frame: 284, there are there are no recognizable objects
# viewed: webcam 1, frame: 271, there are there are no recognizable objects
# viewed: webcam 2, frame: 285, there are there are no recognizable objects
# viewed: webcam 1, frame: 272, there are there are no recognizable objects
# viewed: webcam 2, frame: 286, there are there are no recognizable objects
# viewed: webcam 1, frame: 273, there are there are no recognizable objects
# viewed: webcam 2, frame: 287, there are there are no recognizable objects
# viewed: webcam 1, frame: 274, there are there are no recognizable objects
# viewed: webcam 2, frame: 288, there are there are no recognizable objects
# viewed: webcam 1, frame: 275, there are there are no recognizable objects
# viewed: webcam 2, frame: 289, there are there are no recognizable objects
# viewed: webcam 1, frame: 276, there are there are no recognizable objects
# viewed: webcam 2, frame: 290, there are there are no recognizable objects
# viewed: webcam 1, frame: 277, there are there are no recognizable objects
# viewed: webcam 2, frame: 291, there are there are no recognizable objects
# viewed: webcam 1, frame: 278, there are there are no recognizable objects
# viewed: webcam 2, frame: 292, there are there are no recognizable objects
# viewed: webcam 1, frame: 279, there are there are no recognizable objects
# viewed: webcam 2, frame: 293, there are there are no recognizable objects
# viewed: webcam 1, frame: 280, there are there are no recognizable objects
# viewed: webcam 2, frame: 294, there are there are no recognizable objects
# viewed: webcam 1, frame: 281, there are there are no recognizable objects
# viewed: webcam 2, frame: 295, there are there are no recognizable objects
# viewed: webcam 1, frame: 282, there are there are no recognizable objects
# viewed: webcam 2, frame: 296, there are there are no recognizable objects
# viewed: webcam 1, frame: 283, there are there are no recognizable objects
# viewed: webcam 2, frame: 297, there are there are no recognizable objects
# viewed: webcam 1, frame: 284, there are there are no recognizable objects
# viewed: webcam 2, frame: 298, there are there are no recognizable objects
# viewed: webcam 1, frame: 285, there are there are no recognizable objects
# viewed: webcam 2, frame: 299, there are there are no recognizable objects
# viewed: webcam 1, frame: 286, there are there are no recognizable objects
# viewed: webcam 2, frame: 300, there are there are no recognizable objects
# viewed: webcam 1, frame: 287, there are there are no recognizable objects
# viewed: webcam 2, frame: 301, there are there are no recognizable objects
# viewed: webcam 1, frame: 288, there are there are no recognizable objects
# viewed: webcam 2, frame: 302, there are there are no recognizable objects
# viewed: webcam 1, frame: 289, there are there are no recognizable objects
# viewed: webcam 2, frame: 303, there are there are no recognizable objects
# viewed: webcam 1, frame: 290, there are there are no recognizable objects
# viewed: webcam 2, frame: 304, there are there are no recognizable objects
# viewed: webcam 1, frame: 291, there are there are no recognizable objects
# viewed: webcam 2, frame: 305, there are there are no recognizable objects
# viewed: webcam 1, frame: 292, there are there are no recognizable objects
# viewed: webcam 2, frame: 306, there are there are no recognizable objects
# viewed: webcam 1, frame: 293, there are there are no recognizable objects
# viewed: webcam 2, frame: 307, there are there are no recognizable objects
# viewed: webcam 1, frame: 294, there are there are no recognizable objects
# viewed: webcam 2, frame: 308, there are there are no recognizable objects
# viewed: webcam 1, frame: 295, there are there are no recognizable objects
# viewed: webcam 2, frame: 309, there are there are no recognizable objects
# viewed: webcam 1, frame: 296, there are there are no recognizable objects
# viewed: webcam 2, frame: 310, there are there are no recognizable objects
# viewed: webcam 1, frame: 297, there are there are no recognizable objects
# viewed: webcam 2, frame: 311, there are there are no recognizable objects
# viewed: webcam 1, frame: 298, there are there are no recognizable objects
# viewed: webcam 1, frame: 299, there are there are no recognizable objects
# viewed: webcam 2, frame: 312, there are there are no recognizable objects
# viewed: webcam 1, frame: 300, there are there are no recognizable objects
# viewed: webcam 2, frame: 313, there are there are no recognizable objects
# viewed: webcam 1, frame: 301, there are there are no recognizable objects
# viewed: webcam 2, frame: 314, there are there are no recognizable objects
# viewed: webcam 1, frame: 302, there are there are no recognizable objects
# viewed: webcam 2, frame: 315, there are there are no recognizable objects
# viewed: webcam 1, frame: 303, there are there are no recognizable objects
# viewed: webcam 2, frame: 316, there are there are no recognizable objects
# viewed: webcam 1, frame: 304, there are there are no recognizable objects
# viewed: webcam 2, frame: 317, there are there are no recognizable objects
# viewed: webcam 1, frame: 305, there are there are no recognizable objects
# viewed: webcam 2, frame: 318, there are there are no recognizable objects
# viewed: webcam 1, frame: 306, there are there are no recognizable objects
# viewed: webcam 2, frame: 319, there are there are no recognizable objects
# viewed: webcam 1, frame: 307, there are there are no recognizable objects
# viewed: webcam 2, frame: 320, there are there are no recognizable objects
# viewed: webcam 1, frame: 308, there are there are no recognizable objects
# viewed: webcam 2, frame: 321, there are there are no recognizable objects
# viewed: webcam 1, frame: 309, there are there are no recognizable objects
# viewed: webcam 2, frame: 322, there are there are no recognizable objects
# viewed: webcam 1, frame: 310, there are there are no recognizable objects
# viewed: webcam 2, frame: 323, there are there are no recognizable objects
# viewed: webcam 1, frame: 311, there are there are no recognizable objects
# viewed: webcam 2, frame: 324, there are there are no recognizable objects
# viewed: webcam 1, frame: 312, there are there are no recognizable objects
# viewed: webcam 2, frame: 325, there are there are no recognizable objects
# viewed: webcam 1, frame: 313, there are there are no recognizable objects
# viewed: webcam 2, frame: 326, there are there are no recognizable objects
# viewed: webcam 1, frame: 314, there are there are no recognizable objects
# viewed: webcam 2, frame: 327, there are there are no recognizable objects
# viewed: webcam 1, frame: 315, there are there are no recognizable objects
# viewed: webcam 2, frame: 328, there are there are no recognizable objects
# viewed: webcam 1, frame: 316, there are there are no recognizable objects
# viewed: webcam 2, frame: 329, there are there are no recognizable objects
# viewed: webcam 1, frame: 317, there are there are no recognizable objects
# viewed: webcam 2, frame: 330, there are there are no recognizable objects
# viewed: webcam 1, frame: 318, there are there are no recognizable objects
# viewed: webcam 2, frame: 331, there are there are no recognizable objects
# viewed: webcam 1, frame: 319, there are there are no recognizable objects
# viewed: webcam 2, frame: 332, there are there are no recognizable objects
# viewed: webcam 1, frame: 320, there are there are no recognizable objects
# viewed: webcam 2, frame: 333, there are there are no recognizable objects
# viewed: webcam 1, frame: 321, there are there are no recognizable objects
# viewed: webcam 2, frame: 334, there are there are no recognizable objects
# viewed: webcam 1, frame: 322, there are there are no recognizable objects
# viewed: webcam 2, frame: 335, there are there are no recognizable objects
# viewed: webcam 1, frame: 323, there are there are no recognizable objects
# viewed: webcam 2, frame: 336, there are there are no recognizable objects
# viewed: webcam 1, frame: 324, there are there are no recognizable objects
# viewed: webcam 2, frame: 337, there are there are no recognizable objects
# viewed: webcam 1, frame: 325, there are there are no recognizable objects
# viewed: webcam 2, frame: 338, there are there are no recognizable objects
# viewed: webcam 1, frame: 326, there are there are no recognizable objects
# viewed: webcam 2, frame: 339, there are there are no recognizable objects
# viewed: webcam 1, frame: 327, there are there are no recognizable objects
# viewed: webcam 2, frame: 340, there are there are no recognizable objects
# viewed: webcam 1, frame: 328, there are there are no recognizable objects
# viewed: webcam 2, frame: 341, there are there are no recognizable objects
# viewed: webcam 1, frame: 329, there are there are no recognizable objects
# viewed: webcam 2, frame: 342, there are there are no recognizable objects
# viewed: webcam 1, frame: 330, there are there are no recognizable objects
# viewed: webcam 2, frame: 343, there are there are no recognizable objects
# viewed: webcam 1, frame: 331, there are there are no recognizable objects
# viewed: webcam 2, frame: 344, there are there are no recognizable objects
# viewed: webcam 1, frame: 332, there are there are no recognizable objects
# viewed: webcam 2, frame: 345, there are there are no recognizable objects
# viewed: webcam 2, frame: 346, there are there are no recognizable objects
# viewed: webcam 1, frame: 333, there are there are no recognizable objects
# viewed: webcam 2, frame: 347, there are there are no recognizable objects
# viewed: webcam 1, frame: 334, there are there are no recognizable objects
# viewed: webcam 2, frame: 348, there are there are no recognizable objects
# viewed: webcam 1, frame: 335, there are there are no recognizable objects
# viewed: webcam 2, frame: 349, there are there are no recognizable objects
# viewed: webcam 1, frame: 336, there are there are no recognizable objects
# viewed: webcam 2, frame: 350, there are there are no recognizable objects
# viewed: webcam 1, frame: 337, there are there are no recognizable objects
# viewed: webcam 2, frame: 351, there are there are no recognizable objects
# viewed: webcam 1, frame: 338, there are there are no recognizable objects
# viewed: webcam 2, frame: 352, there are there are no recognizable objects
# viewed: webcam 1, frame: 339, there are there are no recognizable objects
# viewed: webcam 2, frame: 353, there are there are no recognizable objects
# viewed: webcam 1, frame: 340, there are there are no recognizable objects
# viewed: webcam 2, frame: 354, there are there are no recognizable objects
# viewed: webcam 1, frame: 341, there are there are no recognizable objects
# viewed: webcam 2, frame: 355, there are there are no recognizable objects
# viewed: webcam 1, frame: 342, there are there are no recognizable objects
# viewed: webcam 2, frame: 356, there are there are no recognizable objects
# viewed: webcam 1, frame: 343, there are there are no recognizable objects
# viewed: webcam 2, frame: 357, there are there are no recognizable objects
# viewed: webcam 1, frame: 344, there are there are no recognizable objects
# viewed: webcam 1, frame: 345, there are there are no recognizable objects
# viewed: webcam 2, frame: 358, there are there are no recognizable objects
# viewed: webcam 1, frame: 346, there are there are no recognizable objects
# viewed: webcam 2, frame: 359, there are there are no recognizable objects
# viewed: webcam 1, frame: 347, there are there are no recognizable objects
# viewed: webcam 2, frame: 360, there are there are no recognizable objects
# viewed: webcam 1, frame: 348, there are there are no recognizable objects
# viewed: webcam 2, frame: 361, there are there are no recognizable objects
# viewed: webcam 1, frame: 349, there are there are no recognizable objects
# viewed: webcam 2, frame: 362, there are there are no recognizable objects
# viewed: webcam 1, frame: 350, there are there are no recognizable objects
# viewed: webcam 2, frame: 363, there are there are no recognizable objects
# viewed: webcam 1, frame: 351, there are there are no recognizable objects
# viewed: webcam 2, frame: 364, there are there are no recognizable objects
# viewed: webcam 1, frame: 352, there are there are no recognizable objects
# viewed: webcam 2, frame: 365, there are there are no recognizable objects
# viewed: webcam 1, frame: 353, there are there are no recognizable objects
# viewed: webcam 2, frame: 366, there are there are no recognizable objects
# viewed: webcam 1, frame: 354, there are there are no recognizable objects
# viewed: webcam 2, frame: 367, there are there are no recognizable objects
# viewed: webcam 1, frame: 355, there are there are no recognizable objects
# viewed: webcam 2, frame: 368, there are there are no recognizable objects
# viewed: webcam 1, frame: 356, there are there are no recognizable objects
# viewed: webcam 2, frame: 369, there are there are no recognizable objects
# viewed: webcam 1, frame: 357, there are there are no recognizable objects
# viewed: webcam 2, frame: 370, there are there are no recognizable objects
# viewed: webcam 1, frame: 358, there are there are no recognizable objects
# viewed: webcam 2, frame: 371, there are there are no recognizable objects
# viewed: webcam 1, frame: 359, there are there are no recognizable objects
# viewed: webcam 2, frame: 372, there are there are no recognizable objects
# viewed: webcam 1, frame: 360, there are there are no recognizable objects
# viewed: webcam 2, frame: 373, there are there are no recognizable objects
# viewed: webcam 1, frame: 361, there are there are no recognizable objects
# viewed: webcam 2, frame: 374, there are there are no recognizable objects
# viewed: webcam 1, frame: 362, there are there are no recognizable objects
# viewed: webcam 2, frame: 375, there are there are no recognizable objects
# viewed: webcam 1, frame: 363, there are there are no recognizable objects
# viewed: webcam 2, frame: 376, there are there are no recognizable objects
# viewed: webcam 1, frame: 364, there are there are no recognizable objects
# viewed: webcam 2, frame: 377, there are there are no recognizable objects
# viewed: webcam 1, frame: 365, there are there are no recognizable objects
# viewed: webcam 2, frame: 378, there are there are no recognizable objects
# viewed: webcam 1, frame: 366, there are there are no recognizable objects
# viewed: webcam 2, frame: 379, there are there are no recognizable objects
# viewed: webcam 1, frame: 367, there are there are no recognizable objects
# viewed: webcam 2, frame: 380, there are there are no recognizable objects
# viewed: webcam 1, frame: 368, there are there are no recognizable objects
# viewed: webcam 2, frame: 381, there are there are no recognizable objects
# viewed: webcam 1, frame: 369, there are there are no recognizable objects
# viewed: webcam 2, frame: 382, there are there are no recognizable objects
# viewed: webcam 1, frame: 370, there are there are no recognizable objects
# viewed: webcam 2, frame: 383, there are there are no recognizable objects
# viewed: webcam 1, frame: 371, there are there are no recognizable objects
# viewed: webcam 2, frame: 384, there are there are no recognizable objects
# viewed: webcam 1, frame: 372, there are there are no recognizable objects
# viewed: webcam 2, frame: 385, there are there are no recognizable objects
# viewed: webcam 1, frame: 373, there are there are no recognizable objects
# viewed: webcam 2, frame: 386, there are there are no recognizable objects
# viewed: webcam 1, frame: 374, there are there are no recognizable objects
# viewed: webcam 2, frame: 387, there are there are no recognizable objects
# viewed: webcam 2, frame: 388, there are there are no recognizable objects
# viewed: webcam 1, frame: 375, there are there are no recognizable objects
# viewed: webcam 2, frame: 389, there are there are no recognizable objects
# viewed: webcam 1, frame: 376, there are there are no recognizable objects
# viewed: webcam 1, frame: 377, there are there are no recognizable objectsviewed: webcam 2, frame: 390, there are there are no recognizable objects
#
# viewed: webcam 1, frame: 378, there are there are no recognizable objects
# viewed: webcam 2, frame: 391, there are there are no recognizable objects
# viewed: webcam 1, frame: 379, there are there are no recognizable objects
# viewed: webcam 2, frame: 392, there are there are no recognizable objects
# viewed: webcam 1, frame: 380, there are there are no recognizable objects
# viewed: webcam 2, frame: 393, there are there are no recognizable objects
# viewed: webcam 1, frame: 381, there are there are no recognizable objects
# viewed: webcam 2, frame: 394, there are there are no recognizable objects
# viewed: webcam 1, frame: 382, there are there are no recognizable objects
# viewed: webcam 2, frame: 395, there are there are no recognizable objects
# viewed: webcam 1, frame: 383, there are there are no recognizable objects
# viewed: webcam 2, frame: 396, there are there are no recognizable objects
# viewed: webcam 1, frame: 384, there are there are no recognizable objects
# viewed: webcam 2, frame: 397, there are there are no recognizable objects
# viewed: webcam 1, frame: 385, there are there are no recognizable objects
# viewed: webcam 2, frame: 398, there are there are no recognizable objects
# viewed: webcam 1, frame: 386, there are there are no recognizable objects
# viewed: webcam 2, frame: 399, there are there are no recognizable objects
# viewed: webcam 1, frame: 387, there are there are no recognizable objects
# viewed: webcam 2, frame: 400, there are there are no recognizable objects
# viewed: webcam 1, frame: 388, there are there are no recognizable objects
# viewed: webcam 2, frame: 401, there are there are no recognizable objects
# viewed: webcam 1, frame: 389, there are there are no recognizable objects
# viewed: webcam 2, frame: 402, there are there are no recognizable objects
# viewed: webcam 1, frame: 390, there are there are no recognizable objects
# viewed: webcam 2, frame: 403, there are there are no recognizable objects
# viewed: webcam 1, frame: 391, there are there are no recognizable objects
# viewed: webcam 2, frame: 404, there are there are no recognizable objects
# viewed: webcam 1, frame: 392, there are there are no recognizable objects
# viewed: webcam 2, frame: 405, there are there are no recognizable objects
# viewed: webcam 1, frame: 393, there are there are no recognizable objects
# viewed: webcam 2, frame: 406, there are there are no recognizable objects
# viewed: webcam 1, frame: 394, there are there are no recognizable objects
# viewed: webcam 2, frame: 407, there are there are no recognizable objects
# viewed: webcam 1, frame: 395, there are there are no recognizable objects
# viewed: webcam 2, frame: 408, there are there are no recognizable objects
# viewed: webcam 1, frame: 396, there are there are no recognizable objects
# viewed: webcam 2, frame: 409, there are there are no recognizable objects
# viewed: webcam 1, frame: 397, there are there are no recognizable objects
# viewed: webcam 2, frame: 410, there are there are no recognizable objects
# viewed: webcam 1, frame: 398, there are there are no recognizable objects
# viewed: webcam 2, frame: 411, there are there are no recognizable objects
# viewed: webcam 1, frame: 399, there are there are no recognizable objects
# viewed: webcam 2, frame: 412, there are there are no recognizable objects
# viewed: webcam 1, frame: 400, there are there are no recognizable objects
# viewed: webcam 2, frame: 413, there are there are no recognizable objects
# viewed: webcam 1, frame: 401, there are there are no recognizable objects
# viewed: webcam 2, frame: 414, there are there are no recognizable objects
# viewed: webcam 1, frame: 402, there are there are no recognizable objects
# viewed: webcam 2, frame: 415, there are there are no recognizable objects
# viewed: webcam 1, frame: 403, there are there are no recognizable objects
# viewed: webcam 2, frame: 416, there are there are no recognizable objects
